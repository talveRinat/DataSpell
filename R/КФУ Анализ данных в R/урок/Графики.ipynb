# %% [markdown]
# # Графики

# %%
x <- rnorm(100)
plot(x)
# Out:
# plot without title

# %%
plot(x)
abline(h=0)
# Out:
# plot without title

# %%
plot(x)
abline(h=c(-1, 1), col=2, lty=2)
# Out:
# plot without title

# %% [markdown]
# # команды высокого уровня
# plot(), hist(), qqnorm(), curve() и тд

# %%
plot(iris[1:2], pch=as.numeric(iris[, 5]))
# Out:
# plot without title

# %%
plot(iris[1:2], pch=as.character(iris[, 5]))
# Out:
# plot without title
