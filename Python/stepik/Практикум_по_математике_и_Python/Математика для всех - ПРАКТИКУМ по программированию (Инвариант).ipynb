# %% [markdown]
# Практикум по программированию
#
# для темы "Инвариант" курса "Математика для всех" Алексея Савватеева на Coursera от МФТИ
#
# https://www.coursera.org/learn/matematika-dlya-vseh/
#
# В рамках практикума необходимо реализовать алгоритмы на произвольных языках программирования для решения некоторых из задач курса в более общем виде, чем они даны в Контрольных работах.
#
# В обсуждениях запрещено публиковать решения исходных задач!
#
#
# Практикум содержит задачи:
#
#     Кучки бумажек (можно ли уравнять + минимальное число ходов)
#     Сумма цифр на километровых столбах
#     "Пятнашки" (можно ли выиграть на поле классического и произвольного размера)

# %% [markdown]
# # Задача 1.1 - кучки бумажек (можно или нет)
#
# На столе лежат n кучек в каждой из которых kiki бумажек. Разрешается за 1 ход игры добавить к 2 любым кучкам по 1 бумажке.
#
# Можно ли по правилам игры уравнять число бумажек в кучках?
#
# Разбор задачи в лекциях
#
# https://www.coursera.org/lecture/matematika-dlya-vseh/kuchki-bumazhiek-9FYEw
#
# Напишите алгоритм, который принимает на вход строку, где через пробел записаны числа бумажек в кучках (в строке столько чисел, сколько кучек на столе), а на выход сообщает возможно ли уравнять число бумажек в кучках. Программа должна уметь выводить 3 сообщения:
#
#     Кучки можно уравнять
#     Кучки нельзя уравнять
#     Ошибка. Кучек слишком мало, чтобы можно было решить задачу.
#
# Последнее сообщение следует выводить только если кучек меньше 2, т.к. только в этом случае операция по правилам игры невозможна.
#
# Sample Input 1:
#
# 1
#
# Sample Output 1:
#
# Ошибка. Кучек слишком мало, чтобы можно было решить задачу.
#
# Sample Input 2:
#
# 1 2 3
#
# Sample Output 2:
#
# Кучки можно уравнять
#
# Sample Input 3:
#
# 1 2 3 4 5 6
#
# Sample Output 3:
#
# Кучки нельзя уравнять

# %%
heaps = list(map(int,input().split()))

if len(heaps)<2:
    print('Ошибка. Кучек слишком мало, чтобы можно было решить задачу.')
    
elif (len(heaps) == 2 & heaps[0] == heaps[1]) | (len(heaps) > 2 and not sum(heaps)%2) | (sum(heaps)%2 & len(heaps)%2):
    print('Кучки можно уравнять')
    
else:
    print('Кучки нельзя уравнять')
# Out:
# 2 4 4
# Кучки можно уравнять

# %%
L = [int(x) for x in input().split()] 
N_piles = len(L)
Start_sum_papers = sum(L)

if N_piles < 2:
        print('Ошибка. Кучек слишком мало, чтобы можно было решить задачу.')
elif  (N_piles == 2 and L[0] != L[1]) or (Start_sum_papers % 2 and not N_piles % 2):
    print('Кучки нельзя уравнять')
else: print('Кучки можно уравнять')
# Out:
# 2 4 4
# Кучки можно уравнять

# %% [markdown]
# # Задача 1.2 - Кучки бумажек (число ходов)
#
# Усовершенствуйте алгоритм, решающий предыдущую задачу так, чтобы он показывал минимальное число ходов за которое можно уравнять число бумажек в кучках и число бумажек, которое окажется в каждой кучке, если задача решаема.
#
#
# Программа должна уметь выводить 3 сообщения:
#
#     m n
#     Кучки нельзя уравнять
#     Ошибка. Кучек слишком мало, чтобы можно было решить задачу.
#
# где m - минимальное число ходов за которое можно уравнять число бумажек в кучках
#
# n - число бумажек в каждой кучке после уравнивания

# %%
heaps = list(map(int,input().split()))
s = sum(heaps)
l = len(heaps)
m = 0

if len(heaps)<2:
    print('Ошибка. Кучек слишком мало, чтобы можно было решить задачу.')
elif (l == 2 and heaps[0] == heaps[1]) or (l > 2 and not s%2) or (s%2 and l%2):
    while len(set(heaps)) != 1:
        heaps.sort()
        heaps[0] +=1
        heaps[1] +=1
        m += 1
    print(m, heaps[0])
else:
    print('Кучки нельзя уравнять')
# Out:
# 1 3 3
# 4 5

# %%
vec = [int(v) for v in input().split()]

def solve_heaps(vec):
    sorted_ = sorted(vec)
    m = 0
    while sorted_[0] != sorted_[-1]:
        m += 1
        sorted_[0] += 1
        sorted_[1] += 1
        sorted_.sort()
    return m, sorted_[0]
    
if len(vec) < 2:
    print('Ошибка. Кучек слишком мало, чтобы можно было решить задачу.')
elif (len(vec) == 2 and vec[0] != vec[1]) or (not len(vec) % 2 and sum(vec)%2):
    print('Кучки нельзя уравнять')
else:
    print(*solve_heaps(vec))

# %%
n = list(map(int,input().split()))

if len(n) < 2:
    print('Ошибка. Кучек слишком мало, чтобы можно было решить задачу.')
    
elif (len(n) == 2 and n[0]!=n[1]) or (not len(n)%2 and sum(n)%2):
    print('Кучки нельзя уравнять')
    
else:
    N1 = sum(n)
    while len(set(n)) != 1:
        n.sort()
        n[0], n[1] = n[0]+1, n[1] + 1
    print(int((sum(n)-N1)/2), n[0])
# Out:
# 1 3 3
# 4 5

# %% [markdown]
# # Задача 2 - Можно ли замостить доминошками фигуру
#
# Разбор оригинальной задачи в лекциях
#
# https://www.coursera.org/lecture/matematika-dlya-vseh/shakhmatnaia-doska-ykJjy
#
# Рассмотрим задачу замощения доминошками произвольного прямоугольника с вырезанными углами. Примеры таких фигур:
#
# ![image.png](attachment:image.png)
#
#
# Легко заметить, что не все из этих полей поддаются замощению.
#
# При этом:
#
#     2х2 не замостить хотя бы из-за его слишком малого размера, нельзя вместить ни одной доминошки.
#     3х3 не замостить потому, что на нём нечётное число клеток. Пол доминошки останется в любом случае
#     4х2, 4х4, 6х2 не замостить по причине из лекции
#     А вот 3х2 и 4х3, 5х2 легко мостятся (причём для 4х3 действительно способов может быть несколько)
#
#
# Напишите алгоритм, который принимает на вход строку, где через пробел записаны 2 числа - размеры прямоугольника.
#
# Считая, что у прямоугольника вырезаны 2 квадрата (правый верхний и левый нижний, аналогично иллюстрации), определите можно ли замостить такую фигуру доминошками. Используйте понятие инварианта для решения задачи.
#
# На выходе программа должна выводить на печать одно из двух сообщений:
#
#     Замостить нельзя
#     Замостить можно
#
# Sample Input 1:
#
# 2 2
#
# Sample Output 1:
#
# Замостить нельзя
#
# Sample Input 2:
#
# 2 3
#
# Sample Output 2:
#
# Замостить можно

# %%
n, m = map(int,input().split())

print(('Замостить нельзя','Замостить можно')[n%2 ^ m%2])
# Out:
# 2 3
# Замостить можно

# %%
print(('Замостить нельзя', 'Замостить можно')[sum(map(int,input().split()))%2])
# Out:
# 2 3
# Замостить можно

# %%
from numpy import zeros


n, m = map(int, input().split())
z = zeros((n, m))

z[::2, ::2] = 1
z[1::2, 1::2] = 1

z[0, -1] = 0
z[-1, 0] = 0

print('Замостить можно') if (m*n-2)/2 == z.sum() else print('Замостить нельзя')
# Out:
# 2 3
# Замостить можно

# %% [markdown]
# # Задача 3 - сумма цифр на километровых столбах
#
# На каждом километре шоссе между селами Петино и Васино стоит столб с табличкой, на одной стороне которой написано, сколько километров до Петино, а на другой – до Васино. Тимофей заметил, что на каждом столбе сумма всех цифр равна N. Найдите расстояние от Петино до Васино.
#
#     Алгоритм принимает на вход 1 число - сумму цифр на километровых столбах (N).
#     На выход алгоритм должен отдавать 1 число - расстояние между Петино и Васино.
#
# Примечание. Сумма цифр может быть любым натуральным числом (в том числе больше 9). Однако, в примерах вывода показан результат только для простейшего случая, чтобы не давать подсказок к решению Контрольной работы.

# %%
def dist(x):
     return (x % 9 + 1) * (10**(x // 9)) - 1

    
print(dist(int(input())))
# Out:
# 18
# 99

# %% [markdown]
# # Задача 4 - пятнашки
#
# Как мы помним из вводной видеолекции про пятнашки, существует 2 вида позиций:
#
# https://www.coursera.org/lecture/matematika-dlya-vseh/piatnashki-vvodnaia-NryDx
#
#     те из которых можно выиграть
#     те из которых выиграть нельзя
#
# Все они в конечном счёте сводятся в результате манипуляций с пятнашками к одной из двух конечных позиций:
#
# ![image.png](attachment:image.png)
#
# В видеолекции было показано, что любую игровую позицию (включая выигрышную) можно записать в виде перестановки, записав значения пятнашек "змейкой". Например:
#
# https://www.coursera.org/lecture/matematika-dlya-vseh/rieshieniie-piatnashiek-ch-2-wiKxF
#
# ![image-2.png](attachment:image-2.png)
#
#
# Выигрышная позиция, соответствует перестановке (1, 2, 3, 4, 8, 7, 6, 5, 9, 10, 11, 12, 15, 14, 13)
#
#
#
# При решении задачи пятнашек мы показали, что при любой разрешённой операции (передвижении пятнашек в пустую ячейку) не меняется чётность такой перестановки.
#
# Рассчитав чётность текущей перестановки и сравнив её с чётностью выигрышной всегда можно точно сказать можем ли мы выиграть по правилам игры (т.е. только с помощью разрешённых операций передвижения пятнашек на пустое место), приведя конфигурацию поля к выигрышной позиции.
#
#
#
# Справочные материалы:
#
#     вводная лекция
#     https://www.coursera.org/lecture/matematika-dlya-vseh/piatnashki-vvodnaia-NryDx
#     решение пятнашек (часть1)
#     https://www.coursera.org/lecture/matematika-dlya-vseh/rieshieniie-piatnashiek-ch-1-l7rXY
#     решение пятнашек (часть2)
#     https://www.coursera.org/lecture/matematika-dlya-vseh/rieshieniie-piatnashiek-ch-2-wiKxF
#     wiki - перестановки
#     https://ru.wikipedia.org/wiki/%D0%9F%D0%B5%D1%80%D0%B5%D1%81%D1%82%D0%B0%D0%BD%D0%BE%D0%B2%D0%BA%D0%B0
#
#
# ## В данном практикуме мы решим задачу: можно ли из текущей позиции по правилам пятнашек выиграть?
#
# Для этого мы сперва реализуем вспомогательную функцию, определяющую чётность произвольной перестановки.

# %% [markdown]
# # Задача 4.1 - пятнашки (чётность перестановки)
#
#
# Это подготовительная задача. В ней необходимо написать функцию, принимающую на вход список натуральных чисел (перестановку) и возвращающую значение её чётности.
#
# Напомним, что перестановка - это просто список чисел от 1 до n без повторений и пропусков.
#
# Числа могут идти в любом порядке.
#
# Чётность перестановки (упрощённо) - это чётность числа "неправильных пар".
#
#     Правильная пара - 1, 7 (1 идёт раньше 7, и стоит в перестановке слева)
#     Неправильная пара - 7, 1 (1 идёт раньше 7, но в перестановке их порядок нарушен)
#
# В рамках данной задачи на вход подаётся список из произвольного числа натуральных чисел, разделённых пробелами.
#
# На выход необходимо подать значение чётности (1 или -1) полученной перестановки.
#
#     1 - чётная
#     -1 - нечётная
#
# Sample Input 1:
#
# 1 2
#
# Sample Output 1:
#
# 1
#
# Sample Input 2:
#
# 2 1
#
# Sample Output 2:
#
# -1
#
# Sample Input 3:
#
# 2 3 1
#
# Sample Output 3:
#
# 1
#
# Sample Input 4:
#
# 5 13 3 7 11 14 6 9 12 2 15 4 8 1 10
#
# Sample Output 4:
#
# -1
#
# Sample Input 5:
#
# 5 13 3 7 11 14 9 6 12 2 15 4 8 1 10
#
# Sample Output 5:
#
# 1
